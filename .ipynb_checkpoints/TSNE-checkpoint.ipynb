# %%
import numpy as np
from sklearn.manifold import TSNE
import pandas as pd

df = pd.read_csv("movies_normalized.csv")
X = df.drop('title',1).values
model = TSNE(n_components=2, random_state=0, method='barnes_hut')
np.set_printoptions(suppress=True)
tsneResults = model.fit_transform(X)

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter
fig = plt.figure(figsize=(50, 50))
ax = fig.add_subplot(2, 5, 10)
plt.scatter(tsneResults[:, 0], tsneResults[:, 1], cmap=plt.cm.Spectral)
ax.xaxis.set_major_formatter(NullFormatter())
ax.yaxis.set_major_formatter(NullFormatter())
plt.axis('tight')

plt.show()

# %%
df_tsne = pd.DataFrame(tsneResults)
df_tsne['title'] = df['title']
df_tsne.to_csv('tsneRes.csv', index=False)

# %%
df_tsne
# Out:
#               0          1                                              title
# 0     -0.082045   1.858336                                            #Horror
# 1     -3.065712  -9.878965                              'Crocodile' Dundee II
# 2      3.357019  -3.578075                                            'G' Men
# 3      8.928553  -3.603022  'Gung Ho!': The Story of Carlson's Makin Islan...
# 4     -6.857207  -4.379127    'Northwest Passage' (Book I -- Rogers' Rangers)
# 5     -5.104165  -3.333175                                 'Til There Was You
# 6      7.871872  -0.752130                               (500) Days of Summer
# 7     -0.812241  -4.742853                ...E tu vivrai nel terrore! L'aldil
# 8      9.423793  -6.055806                                                .45
# 9      6.415944   4.793459                                    .com for Murder
# 10     2.730272   4.199717                                    1 - Nenokkadine
# 11    -5.170385  -9.987939                                     1 chance sur 2
# 12     6.687829   3.256620                                10 Cloverfield Lane
# 13     1.425969  10.692672                    10 Questions for the Dalai Lama
# 14    -6.106676  -1.410268                       10 Rules for Sleeping Around
# 15     6.445906   6.527963                         10 Things I Hate About You
# 16     0.820733  -0.563331                                     10 to Midnight
# 17     2.372806   6.923725                                          10,000 BC
# 18     4.271777 -10.241342                                           100 Feet
# 19    -5.005823   9.839634      100 Ghost Street: The Return of Richard Speck
# 20    -1.425597  -5.968537                                      100 Mile Rule
# 21    -7.393467   3.468575                                         100 Rifles
# 22    -4.803598  -2.292838                                          100 Tears
# 23     5.927249  -4.085153                                     101 Dalmatians
# 24    -5.961193  -8.218206                                     102 Dalmatians
# 25    10.556125   0.153111                                        10th & Wolf
# 26    -7.710423   7.942437                                              11:14
# 27     1.090103   1.639437                                                 12
# 28     4.720136  -5.612510                                       12 Angry Men
# 29   -10.469902  -4.549488                                          12 Rounds
# ...         ...        ...                                                ...
# 9759   1.386946  -6.522414                                      Zombie Hunter
# 9760   4.301596   4.181058                                    Zombie Massacre
# 9761   6.415280   4.781947                                      Zombie Nation
# 9762   6.355702   4.789284                                   Zombie Nightmare
# 9763  -1.090528  -2.964081                                         Zombieland
# 9764   3.896625  -2.027042                              Zombies Vs. Strippers
# 9765  -2.574638   7.123344                                   Zone of the Dead
# 9766  -1.285794   6.377086                                          Zookeeper
# 9767  -1.107435  -1.661421                                          Zoolander
# 9768  -5.986544  -8.212736                                        Zoolander 2
# 9769  -2.409480   1.163732                                               Zoom
# 9770   7.206559  -7.571913                                           Zootopia
# 9771   4.545468  -5.391715                                               Zulu
# 9772  -1.334452 -10.868471                                               Zulu
# 9773  -2.634864   9.800109                                             Zvezda
# 9774  -6.724633   1.349134                                             Zvezda
# 9775   2.316481  -9.392652                                          Zwartboek
# 9776  10.232738  -2.300889                                          Zyzzyx Rd
# 9777  -3.800637   8.407975                                anakkale Yolun Sonu
# 9778   2.530445  -5.535638                                                  i
# 9779  -7.759283   5.331751                                               iBoy
# 9780  -0.073000   1.835817                                           iMurders
# 9781  -3.406047   2.901682                             lltstok meg Terzanyut!
# 9782  -0.866751  10.683907                                                 ri
# 9783  -2.122198   5.749529                   ritsu uchgun Oneamisu no tsubasa
# 9784  -4.796520  -2.314865                                             sxtape
# 9785   4.047079   9.975016              vocateur: The Morton Downey Jr. Movie
# 9786  -7.015075   4.824793                                                xXx
# 9787  -1.045366   1.705982                         xXx: Return of Xander Cage
# 9788  -4.049932   6.564821                            xXx: State of the Union
#
# [9789 rows x 3 columns]

# %%
df = pd.read_csv("movies_kmeans.csv")
df1 = pd.read_csv("tsne_kmeans.csv")

# %%
df["cluster"].value_counts()
# Out:
# cluster_2    3568
# cluster_0    2469
# cluster_3    2222
# cluster_1    1530
# Name: cluster, dtype: int64

# %%
df1["cluster"].value_counts()
# Out:
# cluster_0    2520
# cluster_1    2442
# cluster_2    2420
# cluster_3    2407
# Name: cluster, dtype: int64
